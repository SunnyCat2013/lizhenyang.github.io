# %% [markdown]
# # score 1

# %%
from datetime import date, timedelta
yesterday = date.today() - timedelta(1)
YESTERDAY = yesterday.strftime('%Y-%m-%d')

# %%
print('\n\n Try to get scores of task one \n\n')
print('Warning: use all data from fdm_vdp_aip_item_text_score_chain for now')
sensetive_words_1_1 = '''
    select
      sku_id,
      (
        case
          pass
          when 1 then 10
          else 0
        end
      ) sensetive_words_1_1
    from
      (
        select
          sku_id,
          pass,
          ROW_NUMBER() OVER(
            partition by sku_id
            order by
              date_time desc
          ) as num
        from
          (
            select
              wareid as sku_id,
              pass,
              create_time as date_time
            from
              fdm.fdm_vdp_aip_item_text_score_chain
            where
              type = 1 ---- 标题
              and start_date <= '{YESTERDAY}'
              and end_date > '{YESTERDAY}'
            union all
            select
              wareId as sku_id,
              pass,
              date_time
            from
              fdm.fdm_vc_health_aip_item_text_score_increment
            where
              type = 1
              and dt = '{YESTERDAY}'
          ) t
      ) tt
    where
      tt.num = 1
'''.format(YESTERDAY = YESTERDAY)

sensetive_words_1_1_df = spark.sql(sensetive_words_1_1)

print('Getting sku_inspection_title_brand_1_2')
print('Getting sku_inspection_title_brand_1_3')

sku_inspection_title_brand_1_2 = '''
    select
    item_sku_id as sku_id,
    stack as sku_inspection_title_brand_1_2,
    showed as sku_inspection_title_brand_1_3
    from
    app.app_vdp_sku_inspection_attr_title
    where
    dt = '%s'
    ''' % YESTERDAY


score1_2_3_df = spark.sql(sku_inspection_title_brand_1_2)
# test
print('\n\n Got scores of task one!\n\n')
res = sensetive_words_1_1_df.join(score1_2_3_df, SKU_ID, 'outer')

# %%
print('\n\n Try to get scores of task one \n\n')
print('Warning: use all data from fdm_vdp_aip_item_text_score_chain for now')
sensetive_words_1_1_old = '''
    select
      sku_id,
      (
        case
          pass
          when 1 then 10
          else 0
        end
      ) sensetive_words_1_1
    from
      (
        select
          sku_id,
          pass,
          ROW_NUMBER() OVER(
            partition by sku_id
            order by
              date_time desc
          ) as num
        from
          (
            select
              wareid as sku_id,
              pass,
              create_time as date_time
            from
              fdm.fdm_vdp_aip_item_text_score_chain
            where
              type = 1 ---- 标题
              and start_date <= '{YESTERDAY}'
              and end_date > '{YESTERDAY}'
            union all
            select
              wareId as sku_id,
              pass,
              date_time
            from
              fdm.fdm_vc_health_aip_item_text_score_increment
            where
              type = 1
              and dt = '{YESTERDAY}'
          ) t
      ) tt
    where
      tt.num = 1
'''.format(YESTERDAY = YESTERDAY)

# %%
print('\n\n Try to get scores of task one \n\n')
print('Warning: use all data from fdm_vdp_aip_item_text_score_chain for now')
sensetive_words_1_1_old = '''
            select
              wareid as sku_id,
              pass,
              create_time as date_time
            from
              fdm.fdm_vdp_aip_item_text_score_chain
            where
              type = 1 ---- 标题
              and start_date <= '{YESTERDAY}'
              and end_date > '{YESTERDAY}'
'''.format(YESTERDAY = YESTERDAY)
print sensetive_words_1_1_old
# Out:
#  Try to get scores of task one
#
#
# ...
#
#             select
#               wareid as sku_id,
#               pass,
#               create_time as date_time
#             from
#               fdm.fdm_vdp_aip_item_text_score_chain
#             where
#               type = 1 ---- 标题
#               and start_date <= '2018-08-07'
#               and end_date > '2018-08-07'

# %%
a = '''
select
  count(*)
from
  (
    select
      t.sku_id,
      t.image_key,
      t.score
    from
      (
        select
          sku_id,
          image_key,
          score,
          ROW_NUMBER() OVER(
            partition by sku_id,
            image_key
            order by
              ts desc
          ) as num
        from
          (
            select
              item_sku_id as sku_id,
              image_key,
              score,
            ts
            from
              fdm.fdm_vc_health_aip_item_image_score_increment_chain
            where image_type =1 ----方图
                and start_date<='{YESTERDAY}'
                and end_date>'{YESTERDAY}'
                and date_time='{YESTERDAY}'
                and dt >= '{YESTERDAY}'
            UNION ALL
            select
              item_sku_id as sku_id,
              image_key,
              score,
              update_time as ts
            from
              fdm.fdm_vdp_aip_item_image_score_chain
            where image_type =1 ----方图
          ) table
      ) t
    where
      t.num = 1
  ) out

'''.format(YESTERDAY = '2018-08-06')
print a
# Out:
# select
#   count(*)
# from
#   (
#     select
#       t.sku_id,
#       t.image_key,
#       t.score
#     from
#       (
#         select
#           sku_id,
#           image_key,
#           score,
#           ROW_NUMBER() OVER(
#             partition by sku_id,
#             image_key
#             order by
#               ts desc
#           ) as num
#         from
#           (
#             select
#               item_sku_id as sku_id,
#               image_key,
#               score,
#             ts
#             from
#               fdm.fdm_vc_health_aip_item_image_score_increment_chain
#             where image_type =1 ----方图
#                 and start_date<='2018-08-06'
#                 and end_date>'2018-08-06'
#                 and date_time='2018-08-06'
#                 and dt >= '2018-08-06'
#             UNION ALL
#             select
#               item_sku_id as sku_id,
#               image_key,
#               score,
#               update_time as ts
# ...

# %%
```
+------+------------------+-----------+-----------+-----------+-----------+-----------+------------------+-----------+-----------+-----------+-----------+-----------+
|sku_id|          score_01|score_01_01|score_01_02|score_01_03|score_02_01|score_02_02|          score_03|score_03_01|score_04_02|score_04_03|score_04_04|score_04_05|
+------+------------------+-----------+-----------+-----------+-----------+-----------+------------------+-----------+-----------+-----------+-----------+-----------+
|104638| 5.142857333333332|          0|         10|         10|        0.0|       10.0|7.7142859999999995|         10|       10.0|    7.14286|       10.0|       10.0|
|104638| 5.142857333333332|          0|         10|         10|        0.0|       10.0|7.7142859999999995|         10|       10.0|    7.14286|       10.0|       10.0|
|104638| 5.142857333333332|          0|         10|         10|        0.0|       10.0|7.7142859999999995|         10|       10.0|    7.14286|       10.0|       10.0|
|104638| 5.142857333333332|          0|         10|         10|        0.0|       10.0|7.7142859999999995|         10|       10.0|    7.14286|       10.0|       10.0|
|104638| 5.142857333333332|          0|         10|         10|        0.0|       10.0|7.7142859999999995|         10|       10.0|    7.14286|       10.0|       10.0|
|107160|1.9999999999999998|       null|         10|         10|       null|       null|               3.0|         10|       null|       null|       null|       null|
|108474|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|
|108474|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|
|108474|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|
|108474|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|
|108474|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|
|111079|1.9999999999999998|       null|         10|         10|       null|       null|               3.0|         10|       null|       null|       null|       null|
|111666|1.9999999999999998|       null|         10|         10|       null|       null|               3.0|         10|       null|       null|       null|       null|
|112848|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|
|112848|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|
|112848|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|
|112848|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|
|112848|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|
|112848|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|
|112848|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|
+------+------------------+-----------+-----------+-----------+-----------+-----------+------------------+-----------+-----------+-----------+-----------+-----------+
```

# %%
```
+------+------------------+-----------+-----------+-----------+-----------+-----------+------------------+-----------+-----------+-----------+-----------+-----------+--------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+--------+-----------+-----------+--------+-----------+
|sku_id|          score_01|score_01_01|score_01_02|score_01_03|score_02_01|score_02_02|          score_03|score_03_01|score_04_02|score_04_03|score_04_04|score_04_05|score_02|score_02_03|score_02_04|score_02_05|score_02_06|score_02_07|score_02_08|score_02_09|score_02_10|score_02_11|score_02_12|score_02_13|score_04|score_04_01|score_04_06|score_05|score_05_01|
+------+------------------+-----------+-----------+-----------+-----------+-----------+------------------+-----------+-----------+-----------+-----------+-----------+--------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+--------+-----------+-----------+--------+-----------+
|104638| 5.142857333333332|          0|         10|         10|        0.0|       10.0|7.7142859999999995|         10|       10.0|    7.14286|       10.0|       10.0|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|104638| 5.142857333333332|          0|         10|         10|        0.0|       10.0|7.7142859999999995|         10|       10.0|    7.14286|       10.0|       10.0|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|104638| 5.142857333333332|          0|         10|         10|        0.0|       10.0|7.7142859999999995|         10|       10.0|    7.14286|       10.0|       10.0|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|104638| 5.142857333333332|          0|         10|         10|        0.0|       10.0|7.7142859999999995|         10|       10.0|    7.14286|       10.0|       10.0|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|104638| 5.142857333333332|          0|         10|         10|        0.0|       10.0|7.7142859999999995|         10|       10.0|    7.14286|       10.0|       10.0|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|107160|1.9999999999999998|       null|         10|         10|       null|       null|               3.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|108474|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|108474|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|108474|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|108474|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|108474|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|111079|1.9999999999999998|       null|         10|         10|       null|       null|               3.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|111666|1.9999999999999998|       null|         10|         10|       null|       null|               3.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|112848|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|112848|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|112848|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|112848|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|112848|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|112848|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
|112848|               5.0|         10|         10|         10|        0.0|       10.0|               5.0|         10|       null|       null|       null|       null|    null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|       null|    null|       null|       null|    null|       null|
+------+------------------+-----------+-----------+-----------+-----------+-----------+------------------+-----------+-----------+-----------+-----------+-----------+--------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+-----------+--------+-----------+-----------+--------+-----------+
```

# %%
a = 'sku_id	score_01	score_01_01	score_01_02	score_01_03	score_02	score_02_01	score_02_02	score_02_03	score_02_04	score_02_05	score_02_06	score_02_07	score_02_08	score_02_09	score_02_10	score_02_11	score_02_12	score_02_13	score_03	score_03_01	score_04	score_04_01	score_04_02	score_04_03	score_04_04	score_04_05	score_04_06	score_05	score_05_01'
a = a.strip().split()
for i in a:
    print i + ',',
# Out:
# sku_id, score_01, score_01_01, score_01_02, score_01_03, score_02, score_02_01, score_02_02, score_02_03, score_02_04, score_02_05, score_02_06, score_02_07, score_02_08, score_02_09, score_02_10, score_02_11, score_02_12, score_02_13, score_03, score_03_01, score_04, score_04_01, score_04_02, score_04_03, score_04_04, score_04_05, score_04_06, score_05, score_05_01,

# %%
print u"cannot resolve '`sensetive_words_5_1`' given input columns: [main_img_score_2_2, sku_id, score_app_details_image_count_4_4, score_1, image_key, score_pc_details_image_size_4_5, sku_inspection_title_brand_1_3, rate, score_app_details_image_exist_or_not_4_2, score_3, ext_attr_accuracy_3_1, non_porn_image_2_1, sku_inspection_title_brand_1_2, sensetive_words_1_1, non_porn_image_4_1, image_key, score_app_details_image_size_4_3];;\n'Project [sku_id#263, score_1#296 AS score_01#333, sensetive_words_1_1#4 AS score_01_01#334, sku_inspection_title_brand_1_2#42L AS score_01_02#335L, sku_inspection_title_brand_1_3#43L AS score_01_03#336L, non_porn_image_2_1#103 AS score_02_01#337, main_img_score_2_2#135 AS score_02_02#338, score_3#314 AS score_03#339, ext_attr_accuracy_3_1#146L AS score_03_01#340L, non_porn_image_4_1#199 AS score_04_01#341, score_app_details_image_exist_or_not_4_2#205 AS score_04_02#342, score_app_details_image_size_4_3#206 AS score_04_03#343, score_app_details_image_count_4_4#207 AS score_04_04#344, score_pc_details_image_size_4_5#208 AS score_04_05#345, 'sensetive_words_5_1 AS score_05_01#346]\n+- Project [sku_id#263, sensetive_words_1_1#4, sku_inspection_title_brand_1_2#42L, sku_inspection_title_brand_1_3#43L, main_img_score_2_2#135, image_key#71, non_porn_image_2_1#103, ext_attr_accuracy_3_1#146L, image_key#167, non_porn_image_4_1#199, score_app_details_image_exist_or_not_4_2#205, score_app_details_image_size_4_3#206, score_app_details_image_count_4_4#207, score_pc_details_image_size_4_5#208, rate#279, score_1#296, score_3_func(ext_attr_accuracy_3_1#146L, rate#279) AS score_3#314]\n   +- Project [sku_id#263, sensetive_words_1_1#4, sku_inspection_title_brand_1_2#42L, sku_inspection_title_brand_1_3#43L, main_img_score_2_2#135, image_key#71, non_porn_image_2_1#103, ext_attr_accuracy_3_1#146L, image_key#167, non_porn_image_4_1#199, score_app_details_image_exist_or_not_4_2#205, score_app_details_image_size_4_3#206, score_app_details_image_count_4_4#207, score_pc_details_image_size_4_5#208, rate#279, score_1_func(sensetive_words_1_1#4, sku_inspection_title_brand_1_2#42L, sku_inspection_title_brand_1_3#43L, rate#279) AS score_1#296]\n      +- Project [sku_id#263, sensetive_words_1_1#4, sku_inspection_title_brand_1_2#42L, sku_inspection_title_brand_1_3#43L, main_img_score_2_2#135, image_key#71, non_porn_image_2_1#103, ext_attr_accuracy_3_1#146L, image_key#167, non_porn_image_4_1#199, score_app_details_image_exist_or_not_4_2#205, score_app_details_image_size_4_3#206, score_app_details_image_count_4_4#207, score_pc_details_image_size_4_5#208, total_score_func(sensetive_words_1_1#4, sku_inspection_title_brand_1_2#42L, sku_inspection_title_brand_1_3#43L, non_porn_image_2_1#103, main_img_score_2_2#135, ext_attr_accuracy_3_1#146L, score_app_details_image_exist_or_not_4_2#205, score_app_details_image_size_4_3#206, score_app_details_image_count_4_4#207, score_pc_details_image_size_4_5#208) AS rate#279]\n         +- Project [coalesce(cast(sku_id#253 as string), cast(sku_id#235L as string)) AS sku_id#263, sensetive_words_1_1#4, sku_inspection_title_brand_1_2#42L, sku_inspection_title_brand_1_3#43L, main_img_score_2_2#135, image_key#71, non_porn_image_2_1#103, ext_attr_accuracy_3_1#146L, image_key#167, non_porn_image_4_1#199, score_app_details_image_exist_or_not_4_2#205, score_app_details_image_size_4_3#206, score_app_details_image_count_4_4#207, score_pc_details_image_size_4_5#208]\n            +- Join FullOuter, (cast(sku_id#253 as double) = cast(sku_id#235L as double))\n               :- Project [coalesce(sku_id#244, sku_id#145) AS sku_id#253, sensetive_words_1_1#4, sku_inspection_title_brand_1_2#42L, sku_inspection_title_brand_1_3#43L, main_img_score_2_2#135, image_key#71, non_porn_image_2_1#103, ext_attr_accuracy_3_1#146L]\n               :  +- Join FullOuter, (sku_id#244 = sku_id#145)\n               :     :- Project [coalesce(cast(sku_id#53 as string), cast(sku_id#139L as string)) AS sku_id#244, sensetive_words_1_1#4, sku_inspection_title_brand_1_2#42L, sku_inspection_title_brand_1_3#43L, main_img_score_2_2#135, image_key#71, non_porn_image_2_1#103]\n               :     :  +- Join FullOuter, (cast(sku_id#53 as double) = cast(sku_id#139L as double))\n               :     :     :- Project [coalesce(sku_id#0, sku_id#41) AS sku_id#53, sensetive_words_1_1#4, sku_inspection_title_brand_1_2#42L, sku_inspection_title_brand_1_3#43L]\n               :     :     :  +- Join FullOuter, (sku_id#0 = sku_id#41)\n               :     :     :     :- Project [sku_id#0, CASE WHEN (pass#22 = 1) THEN 10 ELSE 0 END AS sensetive_words_1_1#4]\n               :     :     :     :  +- Filter (num#3 = 1)\n               :     :     :     :     +- SubqueryAlias tt\n               :     :     :     :        +- Project [sku_id#0, pass#22, num#3]\n               :     :     :     :           +- Project [sku_id#0, pass#22, date_time#1, num#3, num#3]\n               :     :     :     :              +- Window [row_number() windowspecdefinition(sku_id#0, date_time#1 DESC NULLS LAST, ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW) AS num#3], [sku_id#0], [date_time#1 DESC NULLS LAST]\n               :     :     :     :                 +- Project [sku_id#0, pass#22, date_time#1]\n               :     :     :     :                    +- SubqueryAlias t\n               :     :     :     :                       +- Union\n               :     :     :     :                          :- Project [wareid#18 AS sku_id#0, pass#22, create_time#25 AS date_time#1]\n               :     :     :     :                          :  +- Filter (((type#20 = 1) && (start_date#8 <= 2018-08-06)) && (end_date#7 > 2018-08-06))\n               :     :     :     :                          :     +- MetastoreRelation fdm, fdm_vdp_aip_item_text_score_chain\n               :     :     :     :                          +- Project [wareId#28 AS sku_id#2, pass#32, date_time#35]\n               :     :     :     :                             +- Filter ((type#30 = 1) && (dt#26 = 2018-08-06))\n               :     :     :     :                                +- MetastoreRelation fdm, fdm_vc_health_aip_item_text_score_increment\n               :     :     :     +- Project [item_sku_id#45 AS sku_id#41, stack#48L AS sku_inspection_title_brand_1_2#42L, showed#47L AS sku_inspection_title_brand_1_3#43L]\n               :     :     :        +- Filter (dt#44 = 2018-08-06)\n               :     :     :           +- MetastoreRelation app, app_vdp_sku_inspection_attr_title\n               :     :     +- Project [coalesce(sku_id#108L, sku_id#59L) AS sku_id#139L, main_img_score_2_2#135, image_key#71, non_porn_image_2_1#103]\n               :     :        +- Join FullOuter, (sku_id#108L = sku_id#59L)\n               :     :           :- Project [sku_id#108L, <lambda>(main_img_score_2_2#109L) AS main_img_score_2_2#135]\n               :     :           :  +- Aggregate [item_sku_id#123L], [item_sku_id#123L AS sku_id#108L, count(image_key#125) AS main_img_score_2_2#109L]\n               :     :           :     +- Filter (image_type#126 = 1)\n               :     :           :        +- MetastoreRelation fdm, fdm_vdp_aip_item_image_score_1_chain\n               :     :           +- Project [sku_id#59L, image_key#71, non_porn_image_2_1_func(score#74) AS non_porn_image_2_1#103]\n               :     :              +- Project [sku_id#59L, image_key#71, score#74]\n               :     :                 +- Filter (num#62 = 1)\n               :     :                    +- SubqueryAlias t\n               :     :                       +- Project [sku_id#59L, image_key#71, score#74, num#62]\n               :     :                          +- Project [sku_id#59L, image_key#71, score#74, ts#76, num#62, num#62]\n               :     :                             +- Window [row_number() windowspecdefinition(sku_id#59L, image_key#71, ts#76 DESC NULLS LAST, ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW) AS num#62], [sku_id#59L, image_key#71], [ts#76 DESC NULLS LAST]\n               :     :                                +- Project [sku_id#59L, image_key#71, score#74, ts#76]\n               :     :                                   +- SubqueryAlias table\n               :     :                                      +- Union\n               :     :                                         :- Project [item_sku_id#69L AS sku_id#59L, image_key#71, score#74, ts#76]\n               :     :                                         :  +- Filter ((((image_type#72 = 1) && (start_date#66 <= 2018-08-06)) && (end_date#65 > 2018-08-06)) && ((date_time#75 = 2018-08-06) && (dt#64 >= 2018-08-06)))\n               :     :                                         :     +- MetastoreRelation fdm, fdm_vc_health_aip_item_image_score_increment_chain\n               :     :                                         +- Project [item_sku_id#90L AS sku_id#60L, image_key#92, score#95, update_time#97 AS ts#61]\n               :     :                                            +- Filter (image_type#93 = 1)\n               :     :                                               +- MetastoreRelation fdm, fdm_vdp_aip_item_image_score_chain\n               :     +- Project [item_sku_id#148 AS sku_id#145, attr#149L AS ext_attr_accuracy_3_1#146L]\n               :        +- Filter (dt#147 = 2018-08-06)\n               :           +- MetastoreRelation app, app_vdp_sku_inspection_attr_title\n               +- Project [coalesce(sku_id#155L, sku_id#204L) AS sku_id#235L, image_key#167, non_porn_image_4_1#199, score_app_details_image_exist_or_not_4_2#205, score_app_details_image_size_4_3#206, score_app_details_image_count_4_4#207, score_pc_details_image_size_4_5#208]\n                  +- Join FullOuter, (sku_id#155L = sku_id#204L)\n                     :- Project [sku_id#155L, image_key#167, non_porn_image_2_1_func(score#170) AS non_porn_image_4_1#199]\n                     :  +- Project [sku_id#155L, image_key#167, score#170]\n                     :     +- Filter (num#158 = 1)\n                     :        +- SubqueryAlias t\n                     :           +- Project [sku_id#155L, image_key#167, score#170, num#158]\n                     :              +- Project [sku_id#155L, image_key#167, score#170, ts#172, num#158, num#158]\n                     :                 +- Window [row_number() windowspecdefinition(sku_id#155L, image_key#167, ts#172 DESC NULLS LAST, ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW) AS num#158], [sku_id#155L, image_key#167], [ts#172 DESC NULLS LAST]\n                     :                    +- Project [sku_id#155L, image_key#167, score#170, ts#172]\n                     :                       +- SubqueryAlias table\n                     :                          +- Union\n                     :                             :- Project [item_sku_id#165L AS sku_id#155L, image_key#167, score#170, ts#172]\n                     :                             :  +- Filter ((((image_type#168 = 2) && (start_date#162 <= 2018-08-06)) && (end_date#161 > 2018-08-06)) && ((date_time#171 = 2018-08-06) && (dt#160 >= 2018-08-06)))\n                     :                             :     +- MetastoreRelation fdm, fdm_vc_health_aip_item_image_score_increment_chain\n                     :                             +- Project [item_sku_id#186L AS sku_id#156L, image_key#188, score#191, update_time#193 AS ts#157]\n                     :                                +- Filter (image_type#189 = 2)\n                     :                                   +- MetastoreRelation fdm, fdm_vdp_aip_item_image_score_chain\n                     +- Project [item_sku_id#222L AS sku_id#204L, (score_app_details_image_exist_or_not#223 * cast(10 as double)) AS score_app_details_image_exist_or_not_4_2#205, (score_app_details_image_size#224 * cast(10 as double)) AS score_app_details_image_size_4_3#206, (score_app_details_image_count#225 * cast(10 as double)) AS score_app_details_image_count_4_4#207, (score_pc_details_image_size#226 * cast(10 as double)) AS score_pc_details_image_size_4_5#208]\n                        +- MetastoreRelation fdm, fdm_vdp_aip_item_details_page_score_chain\n"
# Out:
# cannot resolve '`sensetive_words_5_1`' given input columns: [main_img_score_2_2, sku_id, score_app_details_image_count_4_4, score_1, image_key, score_pc_details_image_size_4_5, sku_inspection_title_brand_1_3, rate, score_app_details_image_exist_or_not_4_2, score_3, ext_attr_accuracy_3_1, non_porn_image_2_1, sku_inspection_title_brand_1_2, sensetive_words_1_1, non_porn_image_4_1, image_key, score_app_details_image_size_4_3];;
# ...

# %%
a = '''non_porn_image_4_1,
     score_app_details_image_exist_or_not_4_2,
     score_app_details_image_count_4_4,
    score_pc_details_image_size_4_5
'''
a = a.strip().split(',')
for i in a: 
    i = i.strip()
    print ''''%s': %s,''' % (i, i)
for i in a: 
    i = i.strip()
    print ''''scores.%s,''' % ( i)
# Out:
# 'non_porn_image_4_1': non_porn_image_4_1,
# 'score_app_details_image_exist_or_not_4_2': score_app_details_image_exist_or_not_4_2,
# 'score_app_details_image_count_4_4': score_app_details_image_count_4_4,
# 'score_pc_details_image_size_4_5': score_pc_details_image_size_4_5,
# 'scores.non_porn_image_4_1,
# 'scores.score_app_details_image_exist_or_not_4_2,
# 'scores.score_app_details_image_count_4_4,
# 'scores.score_pc_details_image_size_4_5,

# %%
a = '[ 9.99960423e-01 3.95221068e-05]'

# %%
a = a.strip('[]')

# %%
a
# Out:
# ' 9.99960423e-01 3.95221068e-05'

# %%
a = a.strip().split()

# %%
[float(i) for i in a]
# Out:
# [0.999960423, 3.95221068e-05]

# %%
a = '''
   pasoriasis_2_3
    clarity_2_4
    full_screen_2_5
    red_belt_2_6
    su_ning_logo_2_7
    jd_watermark_2_8
    white_2_9
    '''
for i in a.strip().split():
    print str(i) + ':', 1
    
    
for i in a.strip().split():
    print ''  
    print '{n}_udf = udf({n}_func)'.format(n = i)
    print '''{n}_df = {n}_df.withColumn('{n}', {n}_udf('score'))'''.format(n = i)
# Out:
# pasoriasis_2_3: 1
# clarity_2_4: 1
# full_screen_2_5: 1
# red_belt_2_6: 1
# su_ning_logo_2_7: 1
# jd_watermark_2_8: 1
# white_2_9: 1
#
# pasoriasis_2_3_udf = udf(pasoriasis_2_3_func)
# pasoriasis_2_3_df = pasoriasis_2_3_df.withColumn('pasoriasis_2_3', pasoriasis_2_3_udf('score'))
#
# clarity_2_4_udf = udf(clarity_2_4_func)
# clarity_2_4_df = clarity_2_4_df.withColumn('clarity_2_4', clarity_2_4_udf('score'))
#
# full_screen_2_5_udf = udf(full_screen_2_5_func)
# full_screen_2_5_df = full_screen_2_5_df.withColumn('full_screen_2_5', full_screen_2_5_udf('score'))
#
# red_belt_2_6_udf = udf(red_belt_2_6_func)
# red_belt_2_6_df = red_belt_2_6_df.withColumn('red_belt_2_6', red_belt_2_6_udf('score'))
#
# su_ning_logo_2_7_udf = udf(su_ning_logo_2_7_func)
# su_ning_logo_2_7_df = su_ning_logo_2_7_df.withColumn('su_ning_logo_2_7', su_ning_logo_2_7_udf('score'))
#
# jd_watermark_2_8_udf = udf(jd_watermark_2_8_func)
# ...

# %%
for i in a.strip().split():
    print 'from udfs import {n}_func'.format(n = i)
# Out:
# from udfs import pasoriasis_2_3_func
# from udfs import clarity_2_4_func
# from udfs import full_screen_2_5_func
# from udfs import red_belt_2_6_func
# from udfs import su_ning_logo_2_7_func
# from udfs import jd_watermark_2_8_func
# from udfs import white_2_9_func

# %%
for i in a.strip().split():
    print '''def {n}_func({n}):
    return {n}\n'''.format(n = i)
# Out:
# def pasoriasis_2_3_func(pasoriasis_2_3):
#     return pasoriasis_2_3
#
# def clarity_2_4_func(clarity_2_4):
#     return clarity_2_4
#
# def full_screen_2_5_func(full_screen_2_5):
#     return full_screen_2_5
#
# def red_belt_2_6_func(red_belt_2_6):
#     return red_belt_2_6
#
# def su_ning_logo_2_7_func(su_ning_logo_2_7):
#     return su_ning_logo_2_7
#
# def jd_watermark_2_8_func(jd_watermark_2_8):
#     return jd_watermark_2_8
#
# def white_2_9_func(white_2_9):
#     return white_2_9

# %%
for i in a.strip().split():
    print '{n}_df,'.format(n = i),
# Out:
# pasoriasis_2_3_df, clarity_2_4_df, full_screen_2_5_df, red_belt_2_6_df, su_ning_logo_2_7_df, jd_watermark_2_8_df, white_2_9_df,

# %%
for i, n in enumerate(a.strip().split()):
    print 'col("{n}").alias("score_02_0{idx}"),'.format(n = n, idx = i + 3)
# Out:
# col("pasoriasis_2_3").alias("score_02_03"),
# col("clarity_2_4").alias("score_02_04"),
# col("full_screen_2_5").alias("score_02_05"),
# col("red_belt_2_6").alias("score_02_06"),
# col("su_ning_logo_2_7").alias("score_02_07"),
# col("jd_watermark_2_8").alias("score_02_08"),
# col("white_2_9").alias("score_02_09"),

# %%
from scoring import load_weights
from pyspark.sql.functions import udf, col, lit
from pyspark.sql.types import FloatType

from pyspark.sql import Row, functions as F
from pyspark.sql.window import Window


from udfs import pasoriasis_2_3_func
from udfs import clarity_2_4_func
from udfs import full_screen_2_5_func
from udfs import red_belt_2_6_func
from udfs import su_ning_logo_2_7_func
from udfs import jd_watermark_2_8_func
from udfs import white_2_9_func


from datetime import date, timedelta
yesterday = date.today() - timedelta(1)
YESTERDAY = yesterday.strftime('%Y-%m-%d')

SKU_ID = 'sku_id'

WEIGHTS = load_weights()

df = spark.sql('select * from fdm.fdm_vdp_aip_primary_image_check_result_chain where pic_type = 2')
df = df.withColumn('row_num', F.row_number().over(Window.partitionBy('sku', 'pic_path', 'check_obj').orderBy(col('date_time').desc())))
df = df.filter('row_num = 1')
df = df.select(col('sku').alias(SKU_ID), col('pic_path').alias('image_key'), col('check_obj'), col('score'))

# pasoriasis_2_3_df = df.filter('check_obj = 3')
# pasoriasis_2_3_udf = udf(pasoriasis_2_3_func)
# pasoriasis_2_3_df = pasoriasis_2_3_df.withColumn('pasoriasis_2_3', pasoriasis_2_3_udf('score'))

# pasoriasis_2_3_df.show()


clarity_2_4_df = df.filter('check_obj = 4')
full_screen_2_5_df = df.filter('check_obj = 5')
red_belt_2_6_df = df.filter('check_obj = 3')
su_ning_logo_2_7_df = df.filter('check_obj = 7')
jd_watermark_2_8_df = df.filter('check_obj = 8')
white_2_9_df = df.filter('check_obj = 5')

clarity_2_4_udf = udf(clarity_2_4_func)
clarity_2_4_df = clarity_2_4_df.withColumn('clarity_2_4', clarity_2_4_udf(col('score').cast('float')))
clarity_2_4_df.show()


full_screen_2_5_udf = udf(full_screen_2_5_func)
full_screen_2_5_df = full_screen_2_5_df.withColumn('full_screen_2_5', full_screen_2_5_udf('score'))

red_belt_2_6_udf = udf(red_belt_2_6_func)
red_belt_2_6_df = red_belt_2_6_df.withColumn('red_belt_2_6', red_belt_2_6_udf('score'))

su_ning_logo_2_7_udf = udf(su_ning_logo_2_7_func)
su_ning_logo_2_7_df = su_ning_logo_2_7_df.withColumn('su_ning_logo_2_7', su_ning_logo_2_7_udf('score'))

jd_watermark_2_8_udf = udf(jd_watermark_2_8_func)
jd_watermark_2_8_df = jd_watermark_2_8_df.withColumn('jd_watermark_2_8', jd_watermark_2_8_udf('score'))

white_2_9_udf = udf(white_2_9_func)
white_2_9_df = white_2_9_df.withColumn('white_2_9', white_2_9_udf('score'))


df_list = [main_img_score_2_2_df, pasoriasis_2_3_df, clarity_2_4_df, full_screen_2_5_df, red_belt_2_6_df, su_ning_logo_2_7_df, jd_watermark_2_8_df, white_2_9_df]

res_df = non_porn_image_2_1_df
for d in df_list:
    res_df = res_df.join(d, SKU_ID, 'outer')
# Out:
#   File "<ipython-input-42-c6f051063e3f>", line 2
#     jd_watermark_2_8_df = df.filter('check_obj = 8')
#     ^
# IndentationError: unexpected indent

# %%
a = '''
non_porn_image_2_1
main_img_score_2_2
   pasoriasis_2_3
    clarity_2_4
    full_screen_2_5
    red_belt_2_6
    su_ning_logo_2_7
    jd_watermark_2_8
    white_2_9
    '''
for i in a.strip().split():
    print '{n},'.format(n = i)
# Out:
# non_porn_image_2_1,
# main_img_score_2_2,
# pasoriasis_2_3,
# clarity_2_4,
# full_screen_2_5,
# red_belt_2_6,
# su_ning_logo_2_7,
# jd_watermark_2_8,
# white_2_9,

# %%
for i in a.strip().split():
    print ''''{n}': {n},'''.format(n = i)
# Out:
# 'non_porn_image_2_1': non_porn_image_2_1,
# 'main_img_score_2_2': main_img_score_2_2,
# 'pasoriasis_2_3': pasoriasis_2_3,
# 'clarity_2_4': clarity_2_4,
# 'full_screen_2_5': full_screen_2_5,
# 'red_belt_2_6': red_belt_2_6,
# 'su_ning_logo_2_7': su_ning_logo_2_7,
# 'jd_watermark_2_8': jd_watermark_2_8,
# 'white_2_9': white_2_9,

# %%
for i in a.strip().split():
    print '''scores.{n},'''.format(n = i)
# Out:
# scores.non_porn_image_2_1,
# scores.main_img_score_2_2,
# scores.pasoriasis_2_3,
# scores.clarity_2_4,
# scores.full_screen_2_5,
# scores.red_belt_2_6,
# scores.su_ning_logo_2_7,
# scores.jd_watermark_2_8,
# scores.white_2_9,

# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext

from scoring import load_weights
from pyspark.sql.functions import udf, col, lit
from pyspark.sql.types import FloatType

from pyspark.sql import Row, functions as F
from pyspark.sql.window import Window


from udfs import pasoriasis_2_3_func
from udfs import clarity_2_4_func
from udfs import full_screen_2_5_func
from udfs import red_belt_2_6_func
from udfs import su_ning_logo_2_7_func
from udfs import jd_watermark_2_8_func
from udfs import white_2_9_func


from datetime import date, timedelta
yesterday = date.today() - timedelta(1)
YESTERDAY = yesterday.strftime('%Y-%m-%d')

SKU_ID = 'sku_id'

WEIGHTS = load_weights()

# %%
non_porn_image_2_1 = '''
        select
          sku_id,
          image_key,
          score
        from
          (
            select
              sku_id,
              image_key,
              score,
              ROW_NUMBER() OVER(
                partition by sku_id,
                image_key
                order by
                  ts desc
              ) as num
            from
              (
                select
                  item_sku_id as sku_id,
                  image_key,
                  score,
                ts
                from
                  fdm.fdm_vc_health_aip_item_image_score_increment_chain
                where image_type =1 ----方图
                    and start_date<='{YESTERDAY}'
                    and end_date>'{YESTERDAY}'
                    and date_time='{YESTERDAY}'
                    and dt >= '{YESTERDAY}'
                UNION ALL
                select
                  item_sku_id as sku_id,
                  image_key,
                  score,
                  update_time as ts
                from
                  fdm.fdm_vdp_aip_item_image_score_chain
                where image_type =1 ----方图
              ) table
          ) t
        where
          t.num = 1
'''.format(YESTERDAY = YESTERDAY)
non_porn_image_2_1_df = spark.sql(non_porn_image_2_1)
non_porn_image_2_1_df = non_porn_image_2_1_df.select('sku_id', 'image_key', udf(non_porn_image_2_1_func, FloatType())('score').alias('non_porn_image_2_1'))


print('Fetching main_img_score_2_2, using all data from fdm_vdp_aip_item_image_score_1_chain')
main_img_score_2_2 = '''
    select
      item_sku_id as sku_id,
      count(image_key) as main_img_score_2_2
    from
        fdm.fdm_vdp_aip_item_image_score_1_chain
    where
      image_type = 1
    group by
      item_sku_id
'''

print('\n\n Got scores of task two!\n\n')
main_img_score_2_2_df  = spark.sql(main_img_score_2_2)
main_img_score_2_2_df = main_img_score_2_2_df.select('sku_id', udf(lambda x: x if x < 10.0 else 10.0, FloatType())('main_img_score_2_2').alias('main_img_score_2_2'))

# main images
df = spark.sql('select * from fdm.fdm_vdp_aip_primary_image_check_result_chain where pic_type = 2')
df = df.withColumn('row_num', F.row_number().over(Window.partitionBy('sku', 'pic_path', 'check_obj').orderBy(col('date_time').desc())))
df = df.filter('row_num = 1')
df = df.select(col('sku').alias(SKU_ID), col('pic_path').alias('image_key'), col('check_obj'), col('score'))

pasoriasis_2_3_df = df.filter('check_obj = 3')
pasoriasis_2_3_udf = udf(pasoriasis_2_3_func)
pasoriasis_2_3_df = pasoriasis_2_3_df.withColumn('pasoriasis_2_3', pasoriasis_2_3_udf('score'))




clarity_2_4_df = df.filter('check_obj = 4')
full_screen_2_5_df = df.filter('check_obj = 5')
red_belt_2_6_df = df.filter('check_obj = 3')
su_ning_logo_2_7_df = df.filter('check_obj = 7')
jd_watermark_2_8_df = df.filter('check_obj = 8')
white_2_9_df = df.filter('check_obj = 5')

clarity_2_4_udf = udf(clarity_2_4_func)
clarity_2_4_df = clarity_2_4_df.withColumn('clarity_2_4', clarity_2_4_udf(col('score')))

full_screen_2_5_udf = udf(full_screen_2_5_func)
full_screen_2_5_df = full_screen_2_5_df.withColumn('full_screen_2_5', full_screen_2_5_udf('score'))

red_belt_2_6_udf = udf(red_belt_2_6_func)
red_belt_2_6_df = red_belt_2_6_df.withColumn('red_belt_2_6', red_belt_2_6_udf('score'))

su_ning_logo_2_7_udf = udf(su_ning_logo_2_7_func)
su_ning_logo_2_7_df = su_ning_logo_2_7_df.withColumn('su_ning_logo_2_7', su_ning_logo_2_7_udf('score'))

jd_watermark_2_8_udf = udf(jd_watermark_2_8_func)
jd_watermark_2_8_df = jd_watermark_2_8_df.withColumn('jd_watermark_2_8', jd_watermark_2_8_udf('score'))

white_2_9_udf = udf(white_2_9_func)
white_2_9_df = white_2_9_df.withColumn('white_2_9', white_2_9_udf('score'))


df_list = [clarity_2_4_df, full_screen_2_5_df, red_belt_2_6_df, su_ning_logo_2_7_df, jd_watermark_2_8_df, white_2_9_df]
main_image_df = pasoriasis_2_3_df.drop('check_obj').drop('score')
for d in df_list:
    d = d.drop('check_obj').drop('score')
    main_image_df = main_image_df.join(d, [SKU_ID, 'image_key'], 'outer')

#df_list = [main_img_score_2_2_df, main_image_df]
res_df = main_image_df.join(non_porn_image_2_1_df, [SKU_ID, 'image_key'], 'left')

res_df = main_img_score_2_2_df.join(res_df, SKU_ID, 'left')

# %%
import math
def normalizeClarity(score):
    return 10.0 / (1 + math.exp(-score/200))
normalizeClarity(300)
# Out:
# 8.807970779778824

# %%
non_porn_image_2_1 = '''select
  *
from
  (
    select
      item_sku_id as sku_id,
      image_key,
      score,
      date_time
    from
      fdm.fdm_vc_health_aip_item_image_score_increment_chain
    where
      image_type = 1
      and start_date <= '{YESTERDAY}'
      and end_date > '{YESTERDAY}'
      and date_time = '{YESTERDAY}'
      and dt >= '{YESTERDAY}'
      and dp = 'ACTIVE'
    UNION ALL
    select
      item_sku_id as sku_id,
      image_key,
      score,
      update_time as date_time
    from
      fdm.fdm_vdp_aip_item_image_score_chain
    where
      image_type = 1
      and dp = 'ACTIVE'
  ) t
'''.format(YESTERDAY = YESTERDAY)
non_porn_image_2_1_df = spark.sql(non_porn_image_2_1)
non_porn_image_2_1_df = non_porn_image_2_1_df.withColumn('row_num', F.row_number().over(Window.partitionBy('sku_id', 'image_key').orderBy(col('date_time').desc())))
non_porn_image_2_1_df = non_porn_image_2_1_df.filter('row_num = 1')
non_porn_image_2_1_df = non_porn_image_2_1_df.select('sku_id', 'image_key', udf(non_porn_image_2_1_func, FloatType())('score').alias('non_porn_image_2_1'))


# main images
df = spark.sql('select * from fdm.fdm_vdp_aip_primary_image_check_result_chain where pic_type = 2')
df = df.withColumn('row_num', F.row_number().over(Window.partitionBy('sku', 'pic_path', 'check_obj').orderBy(col('date_time').desc())))
df = df.filter('row_num = 1')
df = df.select(col('sku').alias(SKU_ID), col('pic_path').alias('image_key'), col('check_obj'), col('score'))

# %%
YESTERDAY = '2018-08-07'

# %%
non_porn_image_2_1 = '''

            select
              *
            from
              (
                select
                  item_sku_id as sku_id,
                  image_key,
                  score,
                ts,
                date_time
                from
                  fdm.fdm_vc_health_aip_item_image_score_increment_chain
                where image_type =1 ----方图
                    and start_date<='{YESTERDAY}'
                    and end_date>'{YESTERDAY}'
                    and date_time='{YESTERDAY}'
                    and dt >= '{YESTERDAY}'
                UNION ALL
                select
                  item_sku_id as sku_id,
                  image_key,
                  score,
                  update_time as ts
                from
                  fdm.fdm_vdp_aip_item_image_score_chain
                where image_type =1 ----方图)t
'''.format(YESTERDAY = YESTERDAY)
print non_porn_image_2_1
# Out:
#             select
#               *
#             from
#               (
#                 select
#                   item_sku_id as sku_id,
#                   image_key,
#                   score,
#                 ts,
#                 date_time
#                 from
#                   fdm.fdm_vc_health_aip_item_image_score_increment_chain
#                 where image_type =1 ----方图
#                     and start_date<='2018-08-07'
#                     and end_date>'2018-08-07'
#                     and date_time='2018-08-07'
#                     and dt >= '2018-08-07'
#                 UNION ALL
#                 select
#                   item_sku_id as sku_id,
#                   image_key,
#                   score,
#                   update_time as ts
#                 from
#                   fdm.fdm_vdp_aip_item_image_score_chain
#                 where image_type =1 ----方图)t

# %% [markdown]
# # test score 3

# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext

from scoring import load_weights
from pyspark.sql.functions import udf, col, lit
from pyspark.sql.types import FloatType

from pyspark.sql import Row, functions as F
from pyspark.sql.window import Window


from udfs import pasoriasis_2_3_func
from udfs import clarity_2_4_func
from udfs import full_screen_2_5_func
from udfs import red_belt_2_6_func
from udfs import su_ning_logo_2_7_func
from udfs import jd_watermark_2_8_func
from udfs import white_2_9_func


from datetime import date, timedelta
yesterday = date.today() - timedelta(1)
YESTERDAY = yesterday.strftime('%Y-%m-%d')

SKU_ID = 'sku_id'

WEIGHTS = load_weights()

# %%
print('\n\n Try to get scores of task three \n\n')
print('Fetching ext_attr_accuracy_3_1')
ext_attr_accuracy_3_1 = '''
    select
    item_sku_id as sku_id,
    attr as ext_attr_accuracy_3_1
    from
    app.app_vdp_sku_inspection_attr_title
    where
    dt = '%s'
    ''' % YESTERDAY
ext_attr_accuracy3_1_df = spark.sql(ext_attr_accuracy_3_1)
print('\n\n Got scores of task three!\n\n')

# %% [markdown]
# # test score 4

# %%
def non_porn_image_2_1_func(score):
    '''
    score: '[{"apiType":3,"score":"2.8607732929231133E-6"},{"apiType":2,"score":"3.3827973311417736E-8"}]'
    return: [0, 10]
    '''
    print('\n\n\n Score:', score, ' \n\n\n')
    try:
        return 10 * (1.0 - max([float(i['score']) for i in eval(score)]))
    except:
        return 0.0

print('\n\n Try to get scores of task four \n\n')
non_porn_image_4_1 = '''
    select
      sku_id,
      image_key,
      score
    from
      (
        select
          sku_id,
          image_key,
          score,
          ROW_NUMBER() OVER(
            partition by sku_id,
            image_key
            order by
              ts desc
          ) as num
        from
          (
            select
              item_sku_id as sku_id,
              image_key,
              score,
            ts
            from
              fdm.fdm_vc_health_aip_item_image_score_increment_chain
            where image_type = 2 ---- 详情页图
                and start_date<='{YESTERDAY}'
                and end_date>'{YESTERDAY}'
                and date_time='{YESTERDAY}'
                and dt >= '{YESTERDAY}'
            UNION ALL
            select
              item_sku_id as sku_id,
              image_key,
              score,
              update_time as ts
            from
              fdm.fdm_vdp_aip_item_image_score_chain
            where image_type = 2 ---- 详情页图
          ) table
      ) t
    where
      t.num = 1
'''.format(YESTERDAY = YESTERDAY)
non_porn_image_4_1_df = spark.sql(non_porn_image_4_1)
# use the save function of non_porn_image_2_1_func
non_porn_image_4_1_df  = non_porn_image_4_1_df.select('sku_id', 'image_key', udf(non_porn_image_2_1_func, FloatType())('score').alias('non_porn_image_4_1'))

print('Using all data from fdm_vdp_aip_item_details_page_score_chain')
score_app_details4_2_3_4_5 = '''
    select
      item_sku_id as sku_id,
      score_app_details_image_exist_or_not * 10 as score_app_details_image_exist_or_not_4_2,
      score_app_details_image_size * 10 as score_app_details_image_size_4_3,
      score_app_details_image_count * 10 as score_app_details_image_count_4_4,
      score_pc_details_image_size * 10 as score_pc_details_image_size_4_5
    from
      fdm.fdm_vdp_aip_item_details_page_score_chain'''

score_app_details4_2_3_4_5_df = spark.sql(score_app_details4_2_3_4_5)
print('\n\n Got scores of task four!\n\n')
return score_app_details4_2_3_4_5_df.join(non_porn_image_4_1_df, SKU_ID, 'left')

# %% [markdown]
# # score 5

# %%
print('\n\n Try to get scores of task one \n\n')
sensetive_words_5_1 = '''
    select
      sku_id,
      (
        case
          pass
          when 1 then 10
          else 0
        end
      ) sensetive_words_5_1
    from
      (
        select
          sku_id,
          pass,
          ROW_NUMBER() OVER(
            partition by sku_id
            order by
              date_time desc
          ) as num
        from
          (
            select
              wareid as sku_id,
              pass,
              create_time as date_time
            from
              fdm.fdm_vdp_aip_item_text_score_chain
            where
              type = 2 ---- 详情页图
              and start_date <= '{YESTERDAY}'
              and end_date > '{YESTERDAY}'
            union all
            select
              wareId as sku_id,
              pass,
              date_time
            from
              fdm.fdm_vc_health_aip_item_text_score_increment
            where
              type = 2
              and dt = '{YESTERDAY}'
          ) t
      ) tt
    where
      tt.num = 1
'''.format(YESTERDAY = YESTERDAY)

sensetive_words_5_1_df = spark.sql(sensetive_words_5_1)
print('\n\n Got scores of task one!\n\n')
return sensetive_words_5_1_df

# %% [markdown]
# # get scores

# %%
def get_scores(spark):
    
print('\n\n\n\n Hello pyspark \n\n\n')
scores = [score_1(spark), score_2(spark), score_3(spark), score_4(spark), score_5(spark)]
union_df = scores[0]
for s in scores[1:]:
    union_df = union_df.join(s, SKU_ID, 'outer')
